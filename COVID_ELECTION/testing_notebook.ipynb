# %%
import os
import numpy as np
import pandas as pd

# %%
c_data = pd.read_csv('us-counties.csv')
c_data = c_data[c_data['date'].str.contains('2020-11-04')]
c_data.sort_values('cases', ascending=False)
# Out:
#               date         county       state     fips   cases  deaths
# 696789  2020-11-04    Los Angeles  California   6037.0  313526    7117
# 698458  2020-11-04  New York City    New York      NaN  271112   24034
# 697199  2020-11-04           Cook    Illinois  17031.0  201176    5541
# 696949  2020-11-04     Miami-Dade     Florida  12086.0  189331    3670
# 699306  2020-11-04         Harris       Texas  48201.0  164445    2841
# ...            ...            ...         ...      ...     ...     ...
# 698844  2020-11-04        Wheeler      Oregon  41069.0       1       0
# 698408  2020-11-04        Harding  New Mexico  35021.0       1       0
# 697577  2020-11-04        Unknown      Kansas      NaN       0      22
# 697808  2020-11-04        Unknown    Maryland      NaN       0      13
# 697906  2020-11-04        Unknown    Michigan      NaN       0       3
#
# [3245 rows x 6 columns]

# %%
c_pop = pd.read_excel('co-est2019-alldata.xlsx')
c_pop['CTYNAME'] = c_pop['CTYNAME'].str.replace(' County', '', regex=False)
c_pop['CTYNAME'] = c_pop['CTYNAME'].str.replace(' Municipality', '', regex=False)
c_pop['CTYNAME'] = c_pop['CTYNAME'].str.replace(' city', '', regex=False)
c_pop['CTYNAME'] = c_pop['CTYNAME'].str.replace(' Borough', '', regex=False)
c_pop = c_pop[c_pop['COUNTY'] != 0]

c_data['population'] = c_pop['POPESTIMATE2019']
c_pop.sort_values('POPESTIMATE2019', ascending=False)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME      CTYNAME  \
# 209       50       4         9      6      37  California  Los Angeles
# 624       50       2         3     17      31    Illinois         Cook
# 2667      50       3         7     48     201       Texas       Harris
# 106       50       4         8      4      13     Arizona     Maricopa
# 227       50       4         9      6      73  California    San Diego
# ...      ...     ...       ...    ...     ...         ...          ...
# 1684      50       2         4     31       5    Nebraska       Arthur
# 2697      50       3         7     48     261       Texas       Kenedy
# 2701      50       3         7     48     269       Texas         King
# 2717      50       3         7     48     301       Texas       Loving
# 560       50       4         9     15       5      Hawaii      Kalawao
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
for county in c_data['County']:
    if c_pop_refine.append(c_pop[c_pop['CTYNAME'].str.contains(place)])
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0         40       3         6      1       0  Alabama            Alabama
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...
